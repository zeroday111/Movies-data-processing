# %%
import pandas as pd

# %%
data = pd.read_csv("/content/movies.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
data.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# 4  \nA prequel, set before the events of Army of ...
#
#                                                STARS    VOTES  RunTime Gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0   NaN
# 1  \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0   NaN
# 2  \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0   NaN
# 3  \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0   NaN
# 4  \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN   NaN

# %%
print(data.shape)
# Out:
# (9999, 9)

# %%
data.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
data.tail()
# Out:
#                   MOVIES      YEAR  \
# 9994      The Imperfects  (2021– )
# 9995              Arcane  (2021– )
# 9996   Heart of Invictus  (2022– )
# 9997      The Imperfects  (2021– )
# 9998      The Imperfects  (2021– )
#
#                                            GENRE  RATING        ONE-LINE  \
# 9994     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
# 9995  \nAnimation, Action, Adventure                 NaN  \nAdd a Plot\n
# 9996            \nDocumentary, Sport                 NaN  \nAdd a Plot\n
# 9997     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
# 9998     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
#
#                                                   STARS VOTES  RunTime Gross
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...   NaN      NaN   NaN
# 9995                                                 \n   NaN      NaN   NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...   NaN      NaN   NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...   NaN      NaN   NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...   NaN      NaN   NaN

# %%
data.isna().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
data=data.drop("Gross", axis=1)

# %%
data.isna().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# dtype: int64

# %%
data=data.drop("RunTime",axis=1)

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# MOVIES      0
# YEAR        0
# GENRE       0
# RATING      0
# ONE-LINE    0
# STARS       0
# VOTES       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8168 entries, 0 to 9979
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    8168 non-null   object
#  1   YEAR      8168 non-null   object
#  2   GENRE     8168 non-null   object
#  3   RATING    8168 non-null   float64
#  4   ONE-LINE  8168 non-null   object
#  5   STARS     8168 non-null   object
#  6   VOTES     8168 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 510.5+ KB

# %%
data.duplicated().sum()
# Out:
# 11

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head(25)
# Out:
#                                  MOVIES         YEAR  \
# 0                         Blood Red Sky       (2021)
# 1   Masters of the Universe: Revelation     (2021– )
# 2                      The Walking Dead  (2010–2022)
# 3                        Rick and Morty     (2013– )
# 5                           Outer Banks     (2020– )
# 6       The Last Letter from Your Lover       (2021)
# 7                                Dexter  (2006–2013)
# 8                     Never Have I Ever     (2020– )
# 9                          Virgin River     (2019– )
# 10                  Gunpowder Milkshake       (2021)
# 11                              Lucifer  (2016–2021)
# 12                    Fear Street: 1994       (2021)
# 13                             Sex/Life     (2021– )
# 14                American Horror Story     (2011– )
# 15                       Grey's Anatomy     (2005– )
# 16                         Breaking Bad  (2008–2013)
# 17                      The Good Doctor     (2017– )
# 18                             Atypical  (2017–2021)
# 19                      Stranger Things     (2016– )
# 20                    Fear Street: 1978       (2021)
# 21                              Friends  (1994–2004)
# 22                            The Flash     (2014– )
# 23                       Peaky Blinders     (2013– )
# 25                            Chernobyl       (2021)
# 26                              Vikings  (2013–2020)
#
#                                          GENRE  RATING  \
# 0       \nAction, Horror, Thriller                 6.1
# 1   \nAnimation, Action, Adventure                 5.0
# 2        \nDrama, Horror, Thriller                 8.2
# 3   \nAnimation, Adventure, Comedy                 9.2
# 5           \nAction, Crime, Drama                 7.6
# 6                 \nDrama, Romance                 6.8
# 7          \nCrime, Drama, Mystery                 8.6
# 8                         \nComedy                 7.9
# 9                 \nDrama, Romance                 7.4
# 10   \nAction, Adventure, Thriller                 6.0
# 11         \nCrime, Drama, Fantasy                 8.1
# 12        \nDrama, Horror, Mystery                 6.2
# 13        \nComedy, Drama, Romance                 5.4
# 14       \nDrama, Horror, Thriller                 8.0
# 15                \nDrama, Romance                 7.5
# 16        \nCrime, Drama, Thriller                 9.4
# 17                         \nDrama                 8.1
# 18                 \nComedy, Drama                 8.3
# 19        \nDrama, Fantasy, Horror                 8.7
# 20        \nDrama, Horror, Mystery                 6.8
# 21               \nComedy, Romance                 8.9
# 22      \nAction, Adventure, Drama                 7.6
# 23                  \nCrime, Drama                 8.8
# 25       \nDrama, History, Romance                 5.0
# 26      \nAction, Adventure, Drama                 8.5
#
#                                              ONE-LINE  \
# 0   \nA woman with a mysterious illness is forced ...
# 1   \nThe war for Eternia begins again in what may...
# 2   \nSheriff Deputy Rick Grimes wakes up from a c...
# 3   \nAn animated series that follows the exploits...
# 5   \nA group of teenagers from the wrong side of ...
# 6   \nA pair of interwoven stories set in the past...
# 7   \nBy day, mild-mannered Dexter is a blood-spat...
# 8   \nThe complicated life of a modern-day first g...
# 9   \nSeeking a fresh start, nurse practitioner Me...
# 10  \nThree generations of women fight back agains...
# 11  \nLucifer Morningstar has decided he's had eno...
# 12  \nA circle of teenage friends accidentally enc...
# 13  \nA suburban mother of two takes a fantasy-cha...
# 14  \nAn anthology series centering on different c...
# 15  \nA drama centered on the personal and profess...
# 16  \nA high school chemistry teacher diagnosed wi...
# 17  \nShaun Murphy, a young surgeon with autism an...
# 18  \nSam, an 18-year-old on the autism spectrum, ...
# 19  \nWhen a young boy disappears, his mother, a p...
# 20  \nShadyside, 1978. School's out for summer and...
# 21  \nFollows the personal and professional lives ...
# 22  \nAfter being struck by lightning, Barry Allen...
# 23  \nA gangster family epic set in 1900s England,...
# 25  \nA story about a heroic fireman who worked as...
# 26  \nVikings transports us to the brutal and myst...
#
#                                                 STARS      VOTES
# 0   \n    Director:\nPeter Thorwarth\n| \n    Star...     21,062
# 1   \n            \n    Stars:\nChris Wood, \nSara...     17,870
# 2   \n            \n    Stars:\nAndrew Lincoln, \n...    885,805
# 3   \n            \n    Stars:\nJustin Roiland, \n...    414,849
# 5   \n            \n    Stars:\nChase Stokes, \nMa...     25,858
# 6   \n    Director:\nAugustine Frizzell\n| \n    S...      5,283
# 7   \n            \n    Stars:\nMichael C. Hall, \...    665,387
# 8   \n            \n    Stars:\nMaitreyi Ramakrish...     34,530
# 9   \n            \n    Stars:\nAlexandra Breckenr...     27,279
# 10  \n    Director:\nNavot Papushado\n| \n    Star...     17,989
# 11  \n            \n    Stars:\nTom Ellis, \nLesle...    264,222
# 12  \n    Director:\nLeigh Janiak\n| \n    Stars:\...     50,148
# 13  \n            \n    Stars:\nSarah Shahi, \nMik...     12,172
# 14  \n            \n    Stars:\nLady Gaga, \nKathy...    286,488
# 15  \n            \n    Stars:\nEllen Pompeo, \nCh...    266,258
# 16  \n            \n    Stars:\nBryan Cranston, \n...  1,552,311
# 17  \n            \n    Stars:\nFreddie Highmore, ...     70,871
# 18  \n            \n    Stars:\nJennifer Jason Lei...     71,544
# 19  \n            \n    Stars:\nMillie Bobby Brown...    885,856
# 20  \n    Director:\nLeigh Janiak\n| \n    Stars:\...     36,634
# 21  \n            \n    Stars:\nJennifer Aniston, ...    880,918
# 22  \n            \n    Stars:\nGrant Gustin, \nCa...    320,264
# 23  \n            \n    Stars:\nCillian Murphy, \n...    393,414
# 25  \n    Director:\nDanila Kozlovskiy\n| \n    St...      4,681
# 26  \n            \n    Stars:\nKatheryn Winnick, ...    459,913

# %%
data['GENRE']= data['GENRE'].str.strip()

# %%
data.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 5                          Outer Banks     (2020– )
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# 5  \nA group of teenagers from the wrong side of ...
#
#                                                STARS    VOTES
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062
# 1  \n            \n    Stars:\nChris Wood, \nSara...   17,870
# 2  \n            \n    Stars:\nAndrew Lincoln, \n...  885,805
# 3  \n            \n    Stars:\nJustin Roiland, \n...  414,849
# 5  \n            \n    Stars:\nChase Stokes, \nMa...   25,858

# %%
data['ONE-LINE']= data['ONE-LINE'].str.strip()
data['STARS']= data['STARS'].str.strip()

# %%
data.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 5                          Outer Banks     (2020– )
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858

# %%
data["YEAR"] = data["YEAR"].str.replace('(', '')
data["YEAR"] = data["YEAR"].str.replace(')', '')
# Out:
# <ipython-input-77-d00b98d4e7a9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["YEAR"] = data["YEAR"].str.replace('(', '')
# <ipython-input-77-d00b98d4e7a9>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["YEAR"] = data["YEAR"].str.replace(')', '')

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation     2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty     2013–
# 5                          Outer Banks     2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858

# %%
data['YEAR']=data['YEAR'].str.strip()

# %%
data["YEAR"] = data["YEAR"].str.replace('-', '')

# %%
# data=data.drop("END-YEAR", axis = 1)

# %%
# data[['STARR-YEAR','END-YEAR',]] = data['YEAR'].str.split('-',expand=True)

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation      2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty      2013–
# 5                          Outer Banks      2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858

# %%
data[['Genre1','Genre2','Genre3']] = data['GENRE'].str.split(',',expand=True)

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation      2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty      2013–
# 5                          Outer Banks      2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES     Genre1  \
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062     Action
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870  Animation
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805      Drama
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849  Animation
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858     Action
#
#        Genre2      Genre3
# 0      Horror    Thriller
# 1      Action   Adventure
# 2      Horror    Thriller
# 3   Adventure      Comedy
# 5       Crime       Drama

# %%
# data['STARS'] = data['STARS'].str.strip('\n')
data[['Director', 'Actor']] = data['STARS'].str.split('|', expand=True)

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation      2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty      2013–
# 5                          Outer Banks      2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES     Genre1  \
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062     Action
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870  Animation
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805      Drama
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849  Animation
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858     Action
#
#        Genre2      Genre3                                           Director  \
# 0      Horror    Thriller                       Director:\nPeter Thorwarth\n
# 1      Action   Adventure  Stars:\nChris Wood, \nSarah Michelle Gellar, \...
# 2      Horror    Thriller  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...
# 3   Adventure      Comedy  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...
# 5       Crime       Drama  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...
#
#                                                Actor
# 0   \n    Stars:\nPeri Baumeister, \nCarl Anton K...
# 1                                               None
# 2                                               None
# 3                                               None
# 5                                               None

# %%
for idx, value in data['Director'].iteritems():
    if 'Stars:' in value:
        data['Actor'][idx], data['Director'][idx] = value, ''

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation      2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty      2013–
# 5                          Outer Banks      2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES     Genre1  \
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062     Action
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870  Animation
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805      Drama
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849  Animation
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858     Action
#
#        Genre2      Genre3                      Director  \
# 0      Horror    Thriller  Director:\nPeter Thorwarth\n
# 1      Action   Adventure
# 2      Horror    Thriller
# 3   Adventure      Comedy
# 5       Crime       Drama
#
#                                                Actor
# 0   \n    Stars:\nPeri Baumeister, \nCarl Anton K...
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...

# %%
data['Director'] = data['Director'].str.replace('Director:', '')
data['Director'] = data['Director'].str.replace('Directors:', '')
data['Actor'] = data['Actor'].str.replace('Stars:', '')
data['Actor'] = data['Actor'].str.replace('Star:', '')

# %%
data['Director'] = data['Director'].str.strip()
data['Actor'] = data['Actor'].str.strip()
data['Actor'] = data['Actor'].str.replace('\n', '')

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation      2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty      2013–
# 5                          Outer Banks      2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE  \
# 0  A woman with a mysterious illness is forced in...
# 1  The war for Eternia begins again in what may b...
# 2  Sheriff Deputy Rick Grimes wakes up from a com...
# 3  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                STARS    VOTES     Genre1  \
# 0  Director:\nPeter Thorwarth\n| \n    Stars:\nPe...   21,062     Action
# 1  Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17,870  Animation
# 2  Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885,805      Drama
# 3  Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414,849  Animation
# 5  Stars:\nChase Stokes, \nMadelyn Cline, \nMadis...   25,858     Action
#
#        Genre2      Genre3         Director  \
# 0      Horror    Thriller  Peter Thorwarth
# 1      Action   Adventure
# 2      Horror    Thriller
# 3   Adventure      Comedy
# 5       Crime       Drama
#
#                                                Actor
# 0  Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1  Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3  Justin Roiland, Chris Parnell, Spencer Grammer...
# 5  Chase Stokes, Madelyn Cline, Madison Bailey, J...

# %%
data.isnull().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8157 entries, 0 to 9979
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    8157 non-null   object
#  1   YEAR      8157 non-null   object
#  2   GENRE     8157 non-null   object
#  3   RATING    8157 non-null   float64
#  4   ONE-LINE  8157 non-null   object
#  5   VOTES     8157 non-null   int64
#  6   Genre1    8157 non-null   object
#  7   Genre2    6076 non-null   object
#  8   Genre3    4251 non-null   object
#  9   Director  8157 non-null   object
#  10  Actor     7858 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1022.8+ KB

# %%
data=data.drop("STARS",axis=1)

# %%
data.head(50)
# Out:
#                                         MOVIES       YEAR  \
# 0                                Blood Red Sky       2021
# 1          Masters of the Universe: Revelation      2021–
# 2                             The Walking Dead  2010–2022
# 3                               Rick and Morty      2013–
# 5                                  Outer Banks      2020–
# 6              The Last Letter from Your Lover       2021
# 7                                       Dexter  2006–2013
# 8                            Never Have I Ever      2020–
# 9                                 Virgin River      2019–
# 10                         Gunpowder Milkshake       2021
# 11                                     Lucifer  2016–2021
# 12                           Fear Street: 1994       2021
# 13                                    Sex/Life      2021–
# 14                       American Horror Story      2011–
# 15                              Grey's Anatomy      2005–
# 16                                Breaking Bad  2008–2013
# 17                             The Good Doctor      2017–
# 18                                    Atypical  2017–2021
# 19                             Stranger Things      2016–
# 20                           Fear Street: 1978       2021
# 21                                     Friends  1994–2004
# 22                                   The Flash      2014–
# 23                              Peaky Blinders      2013–
# 25                                   Chernobyl       2021
# 26                                     Vikings  2013–2020
# 27                            Better Call Saul      2015–
# 28                                Supernatural  2005–2020
# 29                               The Blacklist      2013–
# 30                           Fear Street: 1666       2021
# 31                              Animal Kingdom      2016–
# 32                          Brooklyn Nine-Nine  2013–2022
# 33  NCIS: Naval Criminal Investigative Service      2003–
# 34                                     Kingdom      2019–
# 35                               Modern Family  2009–2020
# 36                                      Titans    I 2018–
# 37                                 The Witcher      2019–
# 38                               Downton Abbey  2010–2015
# 39                          Shingeki no kyojin  2013–2022
# 40                                       Suits  2011–2019
# 41                            La casa de papel  2017–2021
# 42                              Schitt's Creek  2015–2020
# 43                                   Outlander      2014–
# 44                            The Last Kingdom      2015–
# 45                                Black Mirror      2011–
# 46                                       Ozark      2017–
# 47                                   The Crown      2016–
# 48                                 Sweet Tooth      2021–
# 49                            Army of the Dead       2021
# 50                                       Fargo      2014–
# 51                       How I Met Your Mother  2005–2014
#
#                            GENRE  RATING  \
# 0       Action, Horror, Thriller     6.1
# 1   Animation, Action, Adventure     5.0
# 2        Drama, Horror, Thriller     8.2
# 3   Animation, Adventure, Comedy     9.2
# 5           Action, Crime, Drama     7.6
# 6                 Drama, Romance     6.8
# 7          Crime, Drama, Mystery     8.6
# 8                         Comedy     7.9
# 9                 Drama, Romance     7.4
# 10   Action, Adventure, Thriller     6.0
# 11         Crime, Drama, Fantasy     8.1
# 12        Drama, Horror, Mystery     6.2
# 13        Comedy, Drama, Romance     5.4
# 14       Drama, Horror, Thriller     8.0
# 15                Drama, Romance     7.5
# 16        Crime, Drama, Thriller     9.4
# 17                         Drama     8.1
# 18                 Comedy, Drama     8.3
# 19        Drama, Fantasy, Horror     8.7
# 20        Drama, Horror, Mystery     6.8
# 21               Comedy, Romance     8.9
# 22      Action, Adventure, Drama     7.6
# 23                  Crime, Drama     8.8
# 25       Drama, History, Romance     5.0
# 26      Action, Adventure, Drama     8.5
# 27                  Crime, Drama     8.8
# 28        Drama, Fantasy, Horror     8.4
# 29         Crime, Drama, Mystery     8.0
# 30               Horror, Mystery     6.7
# 31                  Crime, Drama     8.2
# 32                 Comedy, Crime     8.4
# 33          Action, Crime, Drama     7.7
# 34        Action, Drama, History     8.4
# 35        Comedy, Drama, Romance     8.4
# 36      Action, Adventure, Crime     7.7
# 37    Action, Adventure, Fantasy     8.2
# 38                Drama, Romance     8.7
# 39  Animation, Action, Adventure     9.0
# 40                 Comedy, Drama     8.4
# 41        Action, Crime, Mystery     8.3
# 42                        Comedy     8.5
# 43       Drama, Fantasy, Romance     8.4
# 44        Action, Drama, History     8.4
# 45       Drama, Sci-Fi, Thriller     8.8
# 46        Crime, Drama, Thriller     8.4
# 47     Biography, Drama, History     8.6
# 48      Action, Adventure, Drama     7.9
# 49         Action, Crime, Horror     5.8
# 50        Crime, Drama, Thriller     8.9
# 51               Comedy, Romance     8.3
#
#                                              ONE-LINE      VOTES     Genre1  \
# 0   A woman with a mysterious illness is forced in...     21,062     Action
# 1   The war for Eternia begins again in what may b...     17,870  Animation
# 2   Sheriff Deputy Rick Grimes wakes up from a com...    885,805      Drama
# 3   An animated series that follows the exploits o...    414,849  Animation
# 5   A group of teenagers from the wrong side of th...     25,858     Action
# 6   A pair of interwoven stories set in the past a...      5,283      Drama
# 7   By day, mild-mannered Dexter is a blood-spatte...    665,387      Crime
# 8   The complicated life of a modern-day first gen...     34,530     Comedy
# 9   Seeking a fresh start, nurse practitioner Meli...     27,279      Drama
# 10  Three generations of women fight back against ...     17,989     Action
# 11  Lucifer Morningstar has decided he's had enoug...    264,222      Crime
# 12  A circle of teenage friends accidentally encou...     50,148      Drama
# 13  A suburban mother of two takes a fantasy-charg...     12,172     Comedy
# 14  An anthology series centering on different cha...    286,488      Drama
# 15  A drama centered on the personal and professio...    266,258      Drama
# 16  A high school chemistry teacher diagnosed with...  1,552,311      Crime
# 17  Shaun Murphy, a young surgeon with autism and ...     70,871      Drama
# 18  Sam, an 18-year-old on the autism spectrum, de...     71,544     Comedy
# 19  When a young boy disappears, his mother, a pol...    885,856      Drama
# 20  Shadyside, 1978. School's out for summer and t...     36,634      Drama
# 21  Follows the personal and professional lives of...    880,918     Comedy
# 22  After being struck by lightning, Barry Allen w...    320,264     Action
# 23  A gangster family epic set in 1900s England, c...    393,414      Crime
# 25  A story about a heroic fireman who worked as o...      4,681      Drama
# 26  Vikings transports us to the brutal and myster...    459,913     Action
# 27  The trials and tribulations of criminal lawyer...    347,857      Crime
# 28  Two brothers follow their father's footsteps a...    404,273      Drama
# 29  A new FBI profiler, Elizabeth Keen, has her en...    213,522      Crime
# 30  The origins of Sarah Fier's curse are finally ...     27,447     Horror
# 31  Centers on a Southern California family, whose...     26,926      Crime
# 32  Comedy series following the exploits of Det. J...    248,583     Comedy
# 33  The cases of the Naval Criminal Investigative ...    125,619     Action
# 34  While strange rumors about their ill King grip...     34,906     Action
# 35  Three different but related families face tria...    378,030     Comedy
# 36  A team of young superheroes combat evil and ot...     73,656     Action
# 37  Geralt of Rivia, a solitary monster hunter, st...    336,484     Action
# 38  A chronicle of the lives of the British aristo...    171,804      Drama
# 39  After his hometown is destroyed and his mother...    242,582  Animation
# 40  On the run from a drug deal gone bad, brillian...    374,263     Comedy
# 41  An unusual group of robbers attempt to carry o...    341,858     Action
# 42  When rich video-store magnate Johnny Rose and ...     90,728     Comedy
# 43  An English combat nurse from 1945 is mysteriou...    134,991      Drama
# 44  As Alfred the Great defends his kingdom from N...     94,650     Action
# 45  An anthology series exploring a twisted, high-...    469,407      Drama
# 46  A financial advisor drags his family from Chic...    206,090      Crime
# 47  Follows the political rivalries and romance of...    169,517  Biography
# 48  A boy who is half human and half deer survives...     37,142     Action
# 49  Following a zombie outbreak in Las Vegas, a gr...    132,378     Action
# 50  Various chronicles of deception, intrigue and ...    341,221      Crime
# 51  A father recounts to his children - through a ...    624,036     Comedy
#
#         Genre2      Genre3            Director  \
# 0       Horror    Thriller     Peter Thorwarth
# 1       Action   Adventure
# 2       Horror    Thriller
# 3    Adventure      Comedy
# 5        Crime       Drama
# 6      Romance        None  Augustine Frizzell
# 7        Drama     Mystery
# 8         None        None
# 9      Romance        None
# 10   Adventure    Thriller     Navot Papushado
# 11       Drama     Fantasy
# 12      Horror     Mystery        Leigh Janiak
# 13       Drama     Romance
# 14      Horror    Thriller
# 15     Romance        None
# 16       Drama    Thriller
# 17        None        None
# 18       Drama        None
# 19     Fantasy      Horror
# 20      Horror     Mystery        Leigh Janiak
# 21     Romance        None
# 22   Adventure       Drama
# 23       Drama        None
# 25     History     Romance   Danila Kozlovskiy
# 26   Adventure       Drama
# 27       Drama        None
# 28     Fantasy      Horror
# 29       Drama     Mystery
# 30     Mystery        None        Leigh Janiak
# 31       Drama        None
# 32       Crime        None
# 33       Crime       Drama
# 34       Drama     History
# 35       Drama     Romance
# 36   Adventure       Crime
# 37   Adventure     Fantasy
# 38     Romance        None
# 39      Action   Adventure
# 40       Drama        None
# 41       Crime     Mystery
# 42        None        None
# 43     Fantasy     Romance
# 44       Drama     History
# 45      Sci-Fi    Thriller
# 46       Drama    Thriller
# 47       Drama     History
# 48   Adventure       Drama
# 49       Crime      Horror         Zack Snyder
# 50       Drama    Thriller
# 51     Romance        None
#
#                                                 Actor
# 0   Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1   Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2   Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3   Justin Roiland, Chris Parnell, Spencer Grammer...
# 5   Chase Stokes, Madelyn Cline, Madison Bailey, J...
# 6   Shailene Woodley, Joe Alwyn, Wendy Nottingham,...
# 7   Michael C. Hall, Jennifer Carpenter, David Zay...
# 8   Maitreyi Ramakrishnan, Poorna Jagannathan, Dar...
# 9   Alexandra Breckenridge, Martin Henderson, Coli...
# 10  Karen Gillan, Lena Headey, Carla Gugino, Miche...
# 11  Tom Ellis, Lesley-Ann Brandt, Lauren German, D...
# 12  Kiana Madeira, Olivia Scott Welch, Benjamin Fl...
# 13  Sarah Shahi, Mike Vogel, Adam Demos, Margaret ...
# 14  Lady Gaga, Kathy Bates, Angela Bassett, Sarah ...
# 15  Ellen Pompeo, Chandra Wilson, James Pickens Jr...
# 16  Bryan Cranston, Aaron Paul, Anna Gunn, Betsy B...
# 17  Freddie Highmore, Hill Harper, Richard Schiff,...
# 18  Jennifer Jason Leigh, Keir Gilchrist, Brigette...
# 19  Millie Bobby Brown, Finn Wolfhard, Winona Ryde...
# 20  Sadie Sink, Emily Rudd, Ryan Simpkins, McCabe ...
# 21  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
# 22  Grant Gustin, Candice Patton, Danielle Panabak...
# 23  Cillian Murphy, Paul Anderson, Helen McCrory, ...
# 25  Danila Kozlovskiy, Oksana Akinshina, Filipp Av...
# 26  Katheryn Winnick, Gustaf Skarsgård, Alexander ...
# 27  Bob Odenkirk, Rhea Seehorn, Jonathan Banks, Pa...
# 28  Jared Padalecki, Jensen Ackles, Jim Beaver, Mi...
# 29  James Spader, Megan Boone, Diego Klattenhoff, ...
# 30  Kiana Madeira, Ashley Zukerman, Gillian Jacobs...
# 31    Shawn Hatosy, Ben Robson, Jake Weary, Finn Cole
# 32  Andy Samberg, Stephanie Beatriz, Terry Crews, ...
# 33  Mark Harmon, David McCallum, Sean Murray, Paul...
# 34    Ju Ji-Hoon, Bae Doona, Kim Sungkyu, Hye-jun Kim
# 35  Ed O'Neill, Sofía Vergara, Julie Bowen, Ty Bur...
# 36  Brenton Thwaites, Teagan Croft, Anna Diop, Rya...
# 37  Henry Cavill, Anna Shaffer, Freya Allan, Adjoa...
# 38  Hugh Bonneville, Phyllis Logan, Elizabeth McGo...
# 39  Yûki Kaji, Marina Inoue, Josh Grelle, Yui Ishi...
# 40  Gabriel Macht, Patrick J. Adams, Meghan Markle...
# 41  Úrsula Corberó, Álvaro Morte, Itziar Ituño, Pe...
# 42  Eugene Levy, Catherine O'Hara, Dan Levy, Annie...
# 43  Caitriona Balfe, Sam Heughan, Duncan Lacroix, ...
# 44  Alexander Dreymon, Eliza Butterworth, Arnas Fe...
# 45  Daniel Lapaine, Hannah John-Kamen, Michaela Co...
# 46  Jason Bateman, Laura Linney, Sofia Hublitz, Sk...
# 47  Claire Foy, Olivia Colman, Imelda Staunton, Ma...
# 48  Nonso Anozie, Christian Convery, Adeel Akhtar,...
# 49  Dave Bautista, Ella Purnell, Ana de la Reguera...
# 50  Billy Bob Thornton, Martin Freeman, Allison To...
# 51  Josh Radnor, Jason Segel, Cobie Smulders, Neil...

# %%
data.describe()
# Out:
#             RATING
# count  8157.000000
# mean      6.920179
# std       1.219589
# min       1.100000
# 25%       6.200000
# 50%       7.100000
# 75%       7.800000
# max       9.900000

# %%
data['VOTES'].describe()
# Out:
# count     8157
# unique    4129
# top          7
# freq        35
# Name: VOTES, dtype: object

# %%
data["VOTES"] = data["VOTES"].str.replace(',', '')

# %%
data['VOTES']=data['VOTES'].astype(int)

# %%
data.describe()
# Out:
#             RATING         VOTES
# count  8157.000000  8.157000e+03
# mean      6.920179  1.516472e+04
# std       1.219589  7.014462e+04
# min       1.100000  5.000000e+00
# 25%       6.200000  1.670000e+02
# 50%       7.100000  7.960000e+02
# 75%       7.800000  3.806000e+03
# max       9.900000  1.713028e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8157 entries, 0 to 9979
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    8157 non-null   object
#  1   YEAR      8157 non-null   object
#  2   GENRE     8157 non-null   object
#  3   RATING    8157 non-null   float64
#  4   ONE-LINE  8157 non-null   object
#  5   VOTES     8157 non-null   int64
#  6   Genre1    8157 non-null   object
#  7   Genre2    6076 non-null   object
#  8   Genre3    4251 non-null   object
#  9   Director  8157 non-null   object
#  10  Actor     7858 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1022.8+ KB

# %%
print(data['GENRE'].value_counts())
# Out:
# Comedy                          740
# Animation, Action, Adventure    601
# Documentary                     444
# Drama                           427
# Crime, Drama, Mystery           292
#                                ...
# Comedy, Crime, Western            1
# Action, Mystery, Romance          1
# Short, Crime, Drama               1
# Short, Action, Adventure          1
# Documentary, Action, Crime        1
# Name: GENRE, Length: 484, dtype: int64

# %%
# data=data.drop('GENRE', axis=1)

# %%
print(data['Genre1'].value_counts())
print(data['Genre2'].value_counts())
print(data['Genre3'].value_counts())
# Out:
# Comedy         1715
# Animation      1395
# Drama          1299
# Documentary    1134
# Action          994
# Crime           676
# Reality-TV      176
# Adventure       143
# Horror          140
# Biography       131
# Game-Show        92
# Family           44
# Thriller         41
# Romance          32
# Short            31
# Music            28
# Fantasy          25
# Mystery          19
# Talk-Show        12
# Sci-Fi           11
# Sport             5
# Western           5
# News              4
# Musical           2
# History           1
# Film-Noir         1
# War               1
# Name: Genre1, dtype: int64
#  Drama          1528
#  Action          833
#  Adventure       557
#  Crime           545
#  Comedy          409
#  Romance         356
#  Mystery         242
#  Fantasy         217
#  Thriller        184
#  Horror          183
#  Reality-TV      157
#  Short           147
#  Family          142
#  History         125
#  Biography       125
#  Music            99
#  Sport            81
#  Sci-Fi           75
#  Musical          26
#  War              10
#  Animation         8
#  Western           7
#  Talk-Show         7
#  News              5
#  Game-Show         3
#  Film-Noir         3
#  Documentary       2
# Name: Genre2, dtype: int64
#  Drama         672
#  Adventure     635
#  Thriller      552
#  Mystery       476
#  Romance       375
#  Comedy        295
#  Fantasy       213
#  Family        185
#  Sci-Fi        184
#  Crime         155
#  History       130
#  Horror        118
#  Sport          74
#  Music          56
#  War            34
#  Musical        24
#  Action         16
#  Reality-TV     15
#  Biography      12
#  News            9
#  Western         8
#  Film-Noir       8
#  Talk-Show       4
#  Game-Show       1
# Name: Genre3, dtype: int64

# %%
data.head()
# Out:
#                                 MOVIES       YEAR  \
# 0                        Blood Red Sky       2021
# 1  Masters of the Universe: Revelation      2021–
# 2                     The Walking Dead  2010–2022
# 3                       Rick and Morty      2013–
# 5                          Outer Banks      2020–
#
#                           GENRE  RATING  \
# 0      Action, Horror, Thriller     6.1
# 1  Animation, Action, Adventure     5.0
# 2       Drama, Horror, Thriller     8.2
# 3  Animation, Adventure, Comedy     9.2
# 5          Action, Crime, Drama     7.6
#
#                                             ONE-LINE   VOTES     Genre1  \
# 0  A woman with a mysterious illness is forced in...   21062     Action
# 1  The war for Eternia begins again in what may b...   17870  Animation
# 2  Sheriff Deputy Rick Grimes wakes up from a com...  885805      Drama
# 3  An animated series that follows the exploits o...  414849  Animation
# 5  A group of teenagers from the wrong side of th...   25858     Action
#
#        Genre2      Genre3         Director  \
# 0      Horror    Thriller  Peter Thorwarth
# 1      Action   Adventure
# 2      Horror    Thriller
# 3   Adventure      Comedy
# 5       Crime       Drama
#
#                                                Actor
# 0  Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1  Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3  Justin Roiland, Chris Parnell, Spencer Grammer...
# 5  Chase Stokes, Madelyn Cline, Madison Bailey, J...

# %%
data['Director'].describe()
# Out:
# count     8157
# unique    3457
# top
# freq      2548
# Name: Director, dtype: object
